# %% [markdown]
# <a href="https://colab.research.google.com/github/CreedSCT/git-lab/blob/main/lab6_git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Git!")
print("Лабораторная работа №6")
print("Google Colab + GitHub")
# Out:
# Hello, Git!
# Лабораторная работа №6
# Google Colab + GitHub
